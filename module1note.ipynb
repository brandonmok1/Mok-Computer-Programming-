# %% [markdown]
# # I created 3 variables. The names are x y and z. X acts as an interger, y is a float, and z is a string. I use the print command to print them.

# %%
x = 15
y = 17.5
z = "surf"


print (x)
print (y)
print (z)
# Out:
# 15
# 17.5
# surf

# %%
jar1 = 5
jar2 = 10 
hello = "hello" 
print(jar1 + jar2 + hello)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 4
#       1 jar1 = 5
#       2 jar2 = 10
#       3 hello = "hello"
# ----> 4 print(jar1 + jar2 + hello)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# # I had an error in my code. You cannot add strings to intergers in a code.

# %%
jar1 = 5
jar2 = 10 
print (jar2) 
jar2 = jar1 
print (jar2)
# Out:
# 10
# 5

# %% [markdown]
# # whatever is on the left of the equal sign gets set to the value on the right of the equal sign

# %%
name = "John" 
age = 8
print ("My name is", name, "and I am", age, "years old!")
# Out:
# My name is John and I am 8 years old!

# %% [markdown]
# # when I am printing multiple things such as string literals and variables all at once, I separate between them in the print statement with commas.

# %%
my_name = "Brandon"

print(my_name.upper())
print(my_name.lower())
print(my_name.title())
# Out:
# BRANDON
# brandon
# Brandon

# %% [markdown]
# ### print is a function. I use it by itself and I put what I want to print in the parenthesis.
# ### .upper() is a method. I use it on a string meaning, I create a string, and then I call .upper() on the string that I want to convert to uppercase.

# %%
my_life = "surfing"

print(my_life.upper())
print(my_life.lower())
print(my_life.title())
